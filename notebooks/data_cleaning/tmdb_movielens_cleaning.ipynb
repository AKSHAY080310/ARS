# %%
import pandas as pd
df_te=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb_movies_te.csv")
df_en=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb_movies_en.csv")
df_hi=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb_movies_hi.csv")
df_kn=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb_movies_kn.csv")
df_ta=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb_movies_ta.csv")
df_en_2026=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb_movies_2026_en.csv")
df_te_2026=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb_movies_2026_te.csv")
df_hi_2026=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb_movies_2026_hi.csv")
df_kn_2026=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb_movies_2026_kn.csv")
df_ta_2026=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb_movies_2026_ta.csv")

# %%
tmdb_merged_df=pd.concat(
    [df_en,df_te,df_hi,df_ta,df_kn,df_en_2026,df_te_2026,df_hi_2026,df_kn_2026,df_ta_2026],ignore_index=True)

# %%
tmdb_merged_df.head()
# Out:
#    tmdb_id                     title release_date  release_year language  \
# 0     4247               Scary Movie   2000-07-07        2000.0       en
# 1       98                 Gladiator   2000-05-04        2000.0       en
# 2     4234                  Scream 3   2000-02-04        2000.0       en
# 3    11688  The Emperor's New Groove   2000-12-15        2000.0       en
# 4       77                   Memento   2000-10-11        2000.0       en
#
#                     genres  popularity  vote_average  vote_count  \
# 0                     [35]     22.2560         6.388      7623.0
# 1             [28, 18, 12]     18.2146         8.223     20647.0
# 2               [27, 9648]     11.5470         6.007      3982.0
# 3  [12, 16, 35, 10751, 14]     11.2891         7.557      7218.0
# 4               [9648, 53]     11.6323         8.176     16025.0
#
#                                             overview  \
# 0  A familiar-looking group of teenagers find the...
# ...

# %%
tmdb_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5175 entries, 0 to 5174
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tmdb_id       5175 non-null   int64
#  1   title         5175 non-null   object
#  2   release_date  5175 non-null   object
#  3   release_year  5075 non-null   float64
#  4   language      5175 non-null   object
#  5   genres        5175 non-null   object
#  6   popularity    5175 non-null   float64
#  7   vote_average  5175 non-null   float64
#  8   vote_count    5075 non-null   float64
#  9   overview      5091 non-null   object
#  10  cast          5127 non-null   object
#  11  director      5049 non-null   object
#  12  keywords      2492 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 525.7+ KB

# %%
tmdb_merged_df=tmdb_merged_df.drop_duplicates(
    subset=["tmdb_id","language"]
)

# %%
tmdb_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5175 entries, 0 to 5174
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tmdb_id       5175 non-null   int64
#  1   title         5175 non-null   object
#  2   release_date  5175 non-null   object
#  3   release_year  5075 non-null   float64
#  4   language      5175 non-null   object
#  5   genres        5175 non-null   object
#  6   popularity    5175 non-null   float64
#  7   vote_average  5175 non-null   float64
#  8   vote_count    5075 non-null   float64
#  9   overview      5091 non-null   object
#  10  cast          5127 non-null   object
#  11  director      5049 non-null   object
#  12  keywords      2492 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 525.7+ KB

# %%
tmdb_merged_df.duplicated(subset=["tmdb_id","language"]).sum()
# Out:
# 0

# %%
tmdb_merged_df.isnull().sum()
# Out:
# tmdb_id            0
# title              0
# release_date       0
# release_year     100
# language           0
# genres             0
# popularity         0
# vote_average       0
# vote_count       100
# overview          84
# cast              48
# director         126
# keywords        2683
# dtype: int64

# %%
tmdb_merged_df["release_date"]=pd.to_datetime(tmdb_merged_df["release_date"],errors="coerce")

# %%
tmdb_merged_df["release_yearr"]=tmdb_merged_df["release_date"].dt.year

# %%
tmdb_merged_df.head()
# Out:
#    tmdb_id                     title release_date  release_year language  \
# 0     4247               Scary Movie   2000-07-07        2000.0       en
# 1       98                 Gladiator   2000-05-04        2000.0       en
# 2     4234                  Scream 3   2000-02-04        2000.0       en
# 3    11688  The Emperor's New Groove   2000-12-15        2000.0       en
# 4       77                   Memento   2000-10-11        2000.0       en
#
#                     genres  popularity  vote_average  vote_count  \
# 0                     [35]     22.2560         6.388      7623.0
# 1             [28, 18, 12]     18.2146         8.223     20647.0
# 2               [27, 9648]     11.5470         6.007      3982.0
# 3  [12, 16, 35, 10751, 14]     11.2891         7.557      7218.0
# 4               [9648, 53]     11.6323         8.176     16025.0
#
#                                             overview  \
# 0  A familiar-looking group of teenagers find the...
# ...

# %%
tmdb_merged_df.isnull().sum()
# Out:
# tmdb_id             0
# title               0
# release_date        0
# release_year      100
# language            0
# genres              0
# popularity          0
# vote_average        0
# vote_count        100
# overview           84
# cast               48
# director          126
# keywords         2683
# release_yearr       0
# dtype: int64

# %%
tmdb_merged_df=tmdb_merged_df.drop(columns=["release_year"])

# %%
tmdb_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5175 entries, 0 to 5174
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tmdb_id        5175 non-null   int64
#  1   title          5175 non-null   object
#  2   release_date   5175 non-null   datetime64[ns]
#  3   language       5175 non-null   object
#  4   genres         5175 non-null   object
#  5   popularity     5175 non-null   float64
#  6   vote_average   5175 non-null   float64
#  7   vote_count     5075 non-null   float64
#  8   overview       5091 non-null   object
#  9   cast           5127 non-null   object
#  10  director       5049 non-null   object
#  11  keywords       2492 non-null   object
#  12  release_yearr  5175 non-null   int32
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(1), object(7)
# memory usage: 505.5+ KB

# %%
tmdb_merged_df["release_year"]=tmdb_merged_df["release_yearr"]

# %%
tmdb_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5175 entries, 0 to 5174
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tmdb_id        5175 non-null   int64
#  1   title          5175 non-null   object
#  2   release_date   5175 non-null   datetime64[ns]
#  3   language       5175 non-null   object
#  4   genres         5175 non-null   object
#  5   popularity     5175 non-null   float64
#  6   vote_average   5175 non-null   float64
#  7   vote_count     5075 non-null   float64
#  8   overview       5091 non-null   object
#  9   cast           5127 non-null   object
#  10  director       5049 non-null   object
#  11  keywords       2492 non-null   object
#  12  release_yearr  5175 non-null   int32
#  13  release_year   5175 non-null   int32
# dtypes: datetime64[ns](1), float64(3), int32(2), int64(1), object(7)
# memory usage: 525.7+ KB

# %%
tmdb_merged_df=tmdb_merged_df.drop(columns=["release_yearr","release_date"])

# %%
tmdb_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5175 entries, 0 to 5174
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tmdb_id       5175 non-null   int64
#  1   title         5175 non-null   object
#  2   language      5175 non-null   object
#  3   genres        5175 non-null   object
#  4   popularity    5175 non-null   float64
#  5   vote_average  5175 non-null   float64
#  6   vote_count    5075 non-null   float64
#  7   overview      5091 non-null   object
#  8   cast          5127 non-null   object
#  9   director      5049 non-null   object
#  10  keywords      2492 non-null   object
#  11  release_year  5175 non-null   int32
# dtypes: float64(3), int32(1), int64(1), object(7)
# memory usage: 465.1+ KB

# %%
tmdb_merged_df["vote_count"]=tmdb_merged_df["vote_count"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 tmdb_merged_df["vote_count"]=tmdb_merged_df["vote_count"].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
import numpy as np
tmdb_merged_df["vote_count"]=tmdb_merged_df["vote_count"].replace([np.inf,-np.inf],np.nan)

# %%
tmdb_merged_df["vote_count"]=tmdb_merged_df["vote_count"].fillna(0)

# %%
tmdb_merged_df["vote_count"].isnull().sum()
# Out:
# 0

# %%
tmdb_merged_df["vote_count"]=tmdb_merged_df["vote_count"].astype(int)

# %%
tmdb_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5175 entries, 0 to 5174
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tmdb_id       5175 non-null   int64
#  1   title         5175 non-null   object
#  2   language      5175 non-null   object
#  3   genres        5175 non-null   object
#  4   popularity    5175 non-null   float64
#  5   vote_average  5175 non-null   float64
#  6   vote_count    5175 non-null   int32
#  7   overview      5091 non-null   object
#  8   cast          5127 non-null   object
#  9   director      5049 non-null   object
#  10  keywords      2492 non-null   object
#  11  release_year  5175 non-null   int32
# dtypes: float64(2), int32(2), int64(1), object(7)
# memory usage: 444.9+ KB

# %%
tmdb_merged_df["overview"]=tmdb_merged_df["overview"].fillna("")
tmdb_merged_df["cast"]=tmdb_merged_df["cast"].fillna("")
tmdb_merged_df["director"]=tmdb_merged_df["director"].fillna("")
tmdb_merged_df["keywords"]=tmdb_merged_df["keywords"].fillna("")

# %%
tmdb_merged_df.isnull().sum()
# Out:
# tmdb_id         0
# title           0
# language        0
# genres          0
# popularity      0
# vote_average    0
# vote_count      0
# overview        0
# cast            0
# director        0
# keywords        0
# release_year    0
# dtype: int64

# %%
tmdb_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5175 entries, 0 to 5174
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tmdb_id       5175 non-null   int64
#  1   title         5175 non-null   object
#  2   language      5175 non-null   object
#  3   genres        5175 non-null   object
#  4   popularity    5175 non-null   float64
#  5   vote_average  5175 non-null   float64
#  6   vote_count    5175 non-null   int32
#  7   overview      5175 non-null   object
#  8   cast          5175 non-null   object
#  9   director      5175 non-null   object
#  10  keywords      5175 non-null   object
#  11  release_year  5175 non-null   int32
# dtypes: float64(2), int32(2), int64(1), object(7)
# memory usage: 444.9+ KB

# %%
tmdb_merged_df.columns
# Out:
# Index(['tmdb_id', 'title', 'language', 'genres', 'popularity', 'vote_average',
#        'vote_count', 'overview', 'cast', 'director', 'keywords',
#        'release_year'],
#       dtype='object')

# %%
genre_df=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\genre_tmdb.csv")

# %%
genre_df.head(20)
# Out:
#     Unnamed: 0  genre_id      genre_names
# 0            0        28           Action
# 1            1        12        Adventure
# 2            2        16        Animation
# 3            3        35           Comedy
# 4            4        80            Crime
# 5            5        99      Documentary
# 6            6        18            Drama
# 7            7     10751           Family
# 8            8        14          Fantasy
# 9            9        36          History
# 10          10        27           Horror
# 11          11     10402            Music
# 12          12      9648          Mystery
# 13          13     10749          Romance
# 14          14       878  Science Fiction
# 15          15     10770         TV Movie
# 16          16        53         Thriller
# 17          17     10752              War
# 18          18        37          Western

# %%
movie_genre_df=pd.read_csv(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\archive (3)\ml-100k\u.genre",
                           header=None,
                           sep="|",
                           names=["genres","genre_id"])

# %%
movie_genre_df.head(20)
# Out:
#          genres  genre_id
# 0       unknown         0
# 1        Action         1
# 2     Adventure         2
# 3     Animation         3
# 4    Children's         4
# 5        Comedy         5
# 6         Crime         6
# 7   Documentary         7
# 8         Drama         8
# 9       Fantasy         9
# 10    Film-Noir        10
# 11       Horror        11
# 12      Musical        12
# 13      Mystery        13
# 14      Romance        14
# 15       Sci-Fi        15
# 16     Thriller        16
# 17          War        17
# 18      Western        18

# %%
genre_df=genre_df.drop(columns=["Unnamed: 0"])

# %%
genre_df.head(20)
# Out:
#     genre_id      genre_names
# 0         28           Action
# 1         12        Adventure
# 2         16        Animation
# 3         35           Comedy
# 4         80            Crime
# 5         99      Documentary
# 6         18            Drama
# 7      10751           Family
# 8         14          Fantasy
# 9         36          History
# 10        27           Horror
# 11     10402            Music
# 12      9648          Mystery
# 13     10749          Romance
# 14       878  Science Fiction
# 15     10770         TV Movie
# 16        53         Thriller
# 17     10752              War
# 18        37          Western

# %%
movie_genre_df["genres"]=movie_genre_df["genres"].str.lower()

# %%
genre_df["genre_names"]=genre_df["genre_names"].str.lower()

# %%
genre_df.head(20)
# Out:
#     genre_id      genre_names
# 0         28           action
# 1         12        adventure
# 2         16        animation
# 3         35           comedy
# 4         80            crime
# 5         99      documentary
# 6         18            drama
# 7      10751           family
# 8         14          fantasy
# 9         36          history
# 10        27           horror
# 11     10402            music
# 12      9648          mystery
# 13     10749          romance
# 14       878  science fiction
# 15     10770         tv movie
# 16        53         thriller
# 17     10752              war
# 18        37          western

# %%
GENRE_NORMALIZATION = {
    "science fiction": "sci-fi",
    "musical":"music",
    "family": "children",
    "children's": "children",
    "film-noir": "noir",
    "tv movie": "",
    "unknown":""
}

# %%
def normalize_genre(name):
    return GENRE_NORMALIZATION.get(name,name)

# %%
genre_df["genre_names"]=genre_df["genre_names"].apply(normalize_genre)

# %%
genre_df.head(20)
# Out:
#     genre_id  genre_names
# 0         28       action
# 1         12    adventure
# 2         16    animation
# 3         35       comedy
# 4         80        crime
# 5         99  documentary
# 6         18        drama
# 7      10751     children
# 8         14      fantasy
# 9         36      history
# 10        27       horror
# 11     10402        music
# 12      9648      mystery
# 13     10749      romance
# 14       878       sci-fi
# 15     10770
# 16        53     thriller
# 17     10752          war
# 18        37      western

# %%
genre_df=genre_df[genre_df["genre_names"]!=""]

# %%
tmdb_genre_map=dict(zip(genre_df["genre_id"],genre_df["genre_names"]))

# %%
def convert_genre_id(genre_list):
    names=[tmdb_genre_map.get(i,"") for i in genre_list]
    names=[g for g in names if g!=""]
    names=list(set(names))
    return " ".join(names)

# %%
import ast
tmdb_merged_df["genres"]=tmdb_merged_df["genres"].apply(ast.literal_eval)

# %%
tmdb_merged_df["genres"]=tmdb_merged_df["genres"].apply(convert_genre_id)

# %%
tmdb_merged_df.head(20)
# Out:
#     tmdb_id                           title language  \
# 0      4247                     Scary Movie       en
# 1        98                       Gladiator       en
# 2      4234                        Scream 3       en
# 3     11688        The Emperor's New Groove       en
# 4        77                         Memento       en
# 5       107                          Snatch       en
# 6      1359                 American Psycho       en
# 7      8871  How the Grinch Stole Christmas       en
# 8      8358                       Cast Away       en
# 9      9532               Final Destination       en
# 10     4327                Charlie's Angels       en
# 11     1900                         Traffic       en
# 12      955          Mission: Impossible II       en
# 13     1443             The Virgin Suicides       en
# 14     2024                     The Patriot       en
# 15     3981                 What Women Want       en
# 16     2123              Me, Myself & Irene       en
# ...

# %%
print(type(tmdb_merged_df["genres"].iloc[0]))
# Out:
# <class 'str'>

# %%
print(tmdb_merged_df["genres"].iloc[0])
print(type(tmdb_merged_df["genres"].iloc[0]))
# Out:
# comedy
# <class 'str'>

# %%
tmdb_merged_df["genres"]=tmdb_merged_df["genres"].apply(lambda x: x.split())

# %%
tmdb_merged_df.to_pickle(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb1.pkl")

# %%
import pandas as pd
df=pd.read_pickle(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\raw\tmdb1.pkl")

# %%
df.columns
# Out:
# Index(['tmdb_id', 'title', 'language', 'genres', 'popularity', 'vote_average',
#        'vote_count', 'overview', 'cast', 'director', 'keywords',
#        'release_year'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# tmdb_id         0
# title           0
# language        0
# genres          0
# popularity      0
# vote_average    0
# vote_count      0
# overview        0
# cast            0
# director        0
# keywords        0
# release_year    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5175 entries, 0 to 5174
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tmdb_id       5175 non-null   int64
#  1   title         5175 non-null   object
#  2   language      5175 non-null   object
#  3   genres        5175 non-null   object
#  4   popularity    5175 non-null   float64
#  5   vote_average  5175 non-null   float64
#  6   vote_count    5175 non-null   int32
#  7   overview      5175 non-null   object
#  8   cast          5175 non-null   object
#  9   director      5175 non-null   object
#  10  keywords      5175 non-null   object
#  11  release_year  5175 non-null   int32
# dtypes: float64(2), int32(2), int64(1), object(7)
# memory usage: 444.9+ KB

# %%
df1=pd.read_pickle(r"C:\Users\aksha\OneDrive\Desktop\ARS(advanced recommendation system)\data\processed\movielens_for_scaling.pkl")

# %%
df1.head(20)
# Out:
#     user_id  item_id  rating  age gender  \
# 0       196      242     3.0   49      M
# 1       186      302     3.0   39      F
# 2        22      377     1.0   25      M
# 3       244       51     2.0   28      M
# 4       166      346     1.0   47      M
# 5       298      474     4.0   44      M
# 6       115      265     2.0   31      M
# 7       253      465     5.0   26      F
# 8       305      451     3.0   23      M
# 9         6       86     3.0   42      M
# 10       62      257     2.0   27      F
# 11      286     1014     5.0   27      M
# 12      200      222     5.0   40      M
# 13      210       40     3.0   39      M
# 14      224       29     3.0   31      F
# 15      303      785     3.0   19      M
# 16      122      387     5.0   32      F
# 17      194      274     2.0   38      M
# 18      291     1042     4.0   19      M
# 19      234     1184     2.0   60      M
#
#                                                 title  \
# ...

# %%
df.head(20)
# Out:
#     tmdb_id                           title language  \
# 0      4247                     Scary Movie       en
# 1        98                       Gladiator       en
# 2      4234                        Scream 3       en
# 3     11688        The Emperor's New Groove       en
# 4        77                         Memento       en
# 5       107                          Snatch       en
# 6      1359                 American Psycho       en
# 7      8871  How the Grinch Stole Christmas       en
# 8      8358                       Cast Away       en
# 9      9532               Final Destination       en
# 10     4327                Charlie's Angels       en
# 11     1900                         Traffic       en
# 12      955          Mission: Impossible II       en
# 13     1443             The Virgin Suicides       en
# 14     2024                     The Patriot       en
# 15     3981                 What Women Want       en
# 16     2123              Me, Myself & Irene       en
# ...

# %%
df["genres"].unique
# Out:
# <bound method Series.unique of 0                                                [comedy]
# 1                              [action, adventure, drama]
# 2                                       [horror, mystery]
# 3       [animation, comedy, children, fantasy, adventure]
# 4                                     [thriller, mystery]
#                               ...
# 5170                                   [thriller, action]
# 5171                             [comedy, drama, romance]
# 5172                                       [music, drama]
# 5173                                   [thriller, horror]
# 5174                                    [thriller, drama]
# Name: genres, Length: 5175, dtype: object>

# %%
df1["genre_label"]=df1["genre_label"].apply(lambda lst: [x.lower() for x in lst])

# %%
unique_genres=df["genres"].str.split().explode().unique

# %%
print(unique_genres)
# Out:
# <bound method Series.unique of 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 5170   NaN
# 5171   NaN
# 5172   NaN
# 5173   NaN
# 5174   NaN
# Name: genres, Length: 5175, dtype: float64>

# %%
GENRE_NORMALIZATION = {
    "science fiction": "sci-fi",
    "musical":"music",
    "family": "children",
    "children's": "children",
    "film-noir": "noir",
    "tv movie": "",
    "unknown":""
}

# %%
def normalize_genre(lt):
    result=[]
    for g in lt:
        g=GENRE_NORMALIZATION.get(g,g)
        if g!="":
            result.append(g)
    return list(set(result))

# %%
df1["genre_label"]=df1["genre_label"].apply(normalize_genre)

# %%
df1.head(6)
# Out:
#    user_id  item_id  rating  age gender  \
# 0      196      242     3.0   49      M
# 1      186      302     3.0   39      F
# 2       22      377     1.0   25      M
# 3      244       51     2.0   28      M
# 4      166      346     1.0   47      M
# 5      298      474     4.0   44      M
#
#                                                title  \
# 0                                       Kolya (1996)
# 1                           L.A. Confidential (1997)
# 2                                Heavyweights (1994)
# 3                         Legends of the Fall (1994)
# 4                                Jackie Brown (1997)
# 5  Dr. Strangelove or: How I Learned to Stop Worr...
#
#                         genre_label  occupation
# 0                          [comedy]      writer
# 1  [thriller, mystery, noir, crime]   executive
# 2                [comedy, children]      writer
# 3    [western, war, drama, romance]  technician
# 4                    [drama, crime]    educator
# ...

# %%
df1["title"]=df1["title"].str.lower()

# %%
df1.head(6)
# Out:
#    user_id  item_id  rating  age gender  \
# 0      196      242     3.0   49      1
# 1      186      302     3.0   39      0
# 2       22      377     1.0   25      1
# 3      244       51     2.0   28      1
# 4      166      346     1.0   47      1
# 5      298      474     4.0   44      1
#
#                                                title  \
# 0                                       kolya (1996)
# 1                           l.a. confidential (1997)
# 2                                heavyweights (1994)
# 3                         legends of the fall (1994)
# 4                                jackie brown (1997)
# 5  dr. strangelove or: how i learned to stop worr...
#
#                         genre_label  occupation
# 0                          [comedy]      writer
# 1  [thriller, mystery, noir, crime]   executive
# 2                [comedy, children]      writer
# 3    [western, war, drama, romance]  technician
# 4                    [drama, crime]    educator
# ...

# %%
df1["genre_label"]=df1["genre_label"].apply(lambda lst:" ".join(lst))

# %%
df1.head(6)
# Out:
#    user_id  item_id  rating  age gender  \
# 0      196      242     3.0   49      1
# 1      186      302     3.0   39      0
# 2       22      377     1.0   25      1
# 3      244       51     2.0   28      1
# 4      166      346     1.0   47      1
# 5      298      474     4.0   44      1
#
#                                                title  \
# 0                                       kolya (1996)
# 1                           l.a. confidential (1997)
# 2                                heavyweights (1994)
# 3                         legends of the fall (1994)
# 4                                jackie brown (1997)
# 5  dr. strangelove or: how i learned to stop worr...
#
#                    genre_label  occupation
# 0                       comedy      writer
# 1  thriller mystery noir crime   executive
# 2              comedy children      writer
# 3    western war drama romance  technician
# 4                  drama crime    educator
# ...

# %%
df["title"]=df["title"].str.lower()

# %%
df["overview"]=df["overview"].str.lower()

# %%
df["cast"]=df["cast"].str.lower()

# %%
df["director"]=df["director"].str.lower()

# %%
df["keywords"]=df["keywords"].str.lower()

# %%
df.head(20)
# Out:
#     tmdb_id                           title language  \
# 0      4247                     scary movie       en
# 1        98                       gladiator       en
# 2      4234                        scream 3       en
# 3     11688        the emperor's new groove       en
# 4        77                         memento       en
# 5       107                          snatch       en
# 6      1359                 american psycho       en
# 7      8871  how the grinch stole christmas       en
# 8      8358                       cast away       en
# 9      9532               final destination       en
# 10     4327                charlie's angels       en
# 11     1900                         traffic       en
# 12      955          mission: impossible ii       en
# 13     1443             the virgin suicides       en
# 14     2024                     the patriot       en
# 15     3981                 what women want       en
# 16     2123              me, myself & irene       en
# ...

# %%
df["genres"]=df["genres"].apply(lambda lst : " ".join(lst))

# %%
df.head(20)
# Out:
#     tmdb_id                           title language  \
# 0      4247                     scary movie       en
# 1        98                       gladiator       en
# 2      4234                        scream 3       en
# 3     11688        the emperor's new groove       en
# 4        77                         memento       en
# 5       107                          snatch       en
# 6      1359                 american psycho       en
# 7      8871  how the grinch stole christmas       en
# 8      8358                       cast away       en
# 9      9532               final destination       en
# 10     4327                charlie's angels       en
# 11     1900                         traffic       en
# 12      955          mission: impossible ii       en
# 13     1443             the virgin suicides       en
# 14     2024                     the patriot       en
# 15     3981                 what women want       en
# 16     2123              me, myself & irene       en
# ...

# %%
df1["gender"]=df1["gender"].map({"M":1,"F":0})

# %%
df1.head()
# Out:
#    user_id  item_id  rating  age gender                       title  \
# 0      196      242     3.0   49      1                kolya (1996)
# 1      186      302     3.0   39      0    l.a. confidential (1997)
# 2       22      377     1.0   25      1         heavyweights (1994)
# 3      244       51     2.0   28      1  legends of the fall (1994)
# 4      166      346     1.0   47      1         jackie brown (1997)
#
#                         genre_label  occupation
# 0                          [comedy]      writer
# 1  [thriller, mystery, noir, crime]   executive
# 2                [comedy, children]      writer
# 3    [western, war, drama, romance]  technician
# 4                    [drama, crime]    educator

# %%
df["cast1"]=df["cast"].str.replace(" ","")

# %%
df.head()
# Out:
#    tmdb_id                     title language  \
# 0     4247               scary movie       en
# 1       98                 gladiator       en
# 2     4234                  scream 3       en
# 3    11688  the emperor's new groove       en
# 4       77                   memento       en
#
#                                         genres  popularity  vote_average  \
# 0                                       comedy     22.2560         6.388
# 1                       action adventure drama     18.2146         8.223
# 2                               horror mystery     11.5470         6.007
# 3  animation comedy children fantasy adventure     11.2891         7.557
# 4                             thriller mystery     11.6323         8.176
#
#    vote_count                                           overview  \
# 0        7623  a familiar-looking group of teenagers find the...
# 1       20647  after the death of emperor marcus aurelius, hi...
# ...

# %%
df.columns
# Out:
# Index(['tmdb_id', 'title', 'language', 'genres', 'popularity', 'vote_average',
#        'vote_count', 'overview', 'cast', 'director', 'keywords',
#        'release_year', 'cast1'],
#       dtype='object')

# %%
df=df.drop(columns=["cast1"])

# %%
df.columns
# Out:
# Index(['tmdb_id', 'title', 'language', 'genres', 'popularity', 'vote_average',
#        'vote_count', 'overview', 'cast', 'director', 'keywords',
#        'release_year'],
#       dtype='object')

# %%
df["combined_features"]=(df["genres"]+" "+df["cast"]+" "+df["director"]+" "+df["overview"]+" "+df["keywords"])

# %%
df["combined_features"]
# Out:
# 0       comedy annafaris reginahall marlonwayans shawn...
# 1       action adventure drama russellcrowe joaquinpho...
# 2       horror mystery nevecampbell courteneycox david...
# 3       animation comedy children fantasy adventure da...
# 4       thriller mystery guypearce carrie-annemoss joe...
#                               ...
# 5170    thriller action saidhanshika kabirduhansingh s...
# 5171    comedy drama romance atharvaamurali fahadhfaas...
# 5172    music drama snehaasesh kabervasuki sruthi sisu...
# 5173    thriller horror f.j. ayraa chandhinitamilarasa...
# 5174    thriller drama m.sasikumar chaithrajachar guru...
# Name: combined_features, Length: 5175, dtype: object

# %%
df.isnull().sum()
# Out:
# tmdb_id              0
# title                0
# language             0
# genres               0
# popularity           0
# vote_average         0
# vote_count           0
# overview             0
# cast                 0
# director             0
# keywords             0
# release_year         0
# combined_features    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5175 entries, 0 to 5174
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tmdb_id            5175 non-null   int64
#  1   title              5175 non-null   object
#  2   language           5175 non-null   object
#  3   genres             5175 non-null   object
#  4   popularity         5175 non-null   float64
#  5   vote_average       5175 non-null   float64
#  6   vote_count         5175 non-null   int32
#  7   overview           5175 non-null   object
#  8   cast               5175 non-null   object
#  9   director           5175 non-null   object
#  10  keywords           5175 non-null   object
#  11  release_year       5175 non-null   int32
#  12  combined_features  5175 non-null   object
# dtypes: float64(2), int32(2), int64(1), object(8)
# memory usage: 485.3+ KB

# %%
df.to_pickle(r"
